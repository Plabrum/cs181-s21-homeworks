# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib notebook

# %%
decay_score = np.load("decay_score.npy")
no_decay_score = np.load("no_decay_score.npy")

# %%
plt.figure(figsize=(8,6))
plt.plot(decay_score)
plt.title("Score vs Epoch with Epsilon Decay")
plt.ylabel("Score")
plt.xlabel("Epoch")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure(figsize=(8,6))
plt.plot(no_decay_score)
plt.title("Score vs Epoch with no Epsilon Decay")
plt.ylabel("Score")
plt.xlabel("Epoch")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
a_g_score = np.load("a_g_score.npy")

# %%
a_g_score
# Out:
# array([[  0.   ,   0.   , 148.125],
#        [  0.   ,   1.   ,  88.25 ],
#        [  0.   ,   2.   ,  11.375],
#        [  0.   ,   3.   ,  19.375],
#        [  1.   ,   0.   ,  19.125],
#        [  1.   ,   1.   , 284.375],
#        [  1.   ,   2.   ,  75.625],
#        [  1.   ,   3.   , 229.5  ],
#        [  2.   ,   0.   , 583.5  ],
#        [  2.   ,   1.   , 258.   ],
#        [  2.   ,   2.   ,  29.   ],
#        [  2.   ,   3.   , 152.625],
#        [  3.   ,   0.   , 496.375],
#        [  3.   ,   1.   ,  33.5  ],
#        [  3.   ,   2.   , 123.   ],
#        [  3.   ,   3.   , 221.75 ]])

# %%
df = pd.DataFrame(a_g_score)
df.columns = ["Alpha", "Gamma", "Score"]
df
# Out:
#     Alpha  Gamma    Score
# 0     0.0    0.0  148.125
# 1     0.0    1.0   88.250
# 2     0.0    2.0   11.375
# 3     0.0    3.0   19.375
# 4     1.0    0.0   19.125
# 5     1.0    1.0  284.375
# 6     1.0    2.0   75.625
# 7     1.0    3.0  229.500
# 8     2.0    0.0  583.500
# 9     2.0    1.0  258.000
# 10    2.0    2.0   29.000
# 11    2.0    3.0  152.625
# 12    3.0    0.0  496.375
# 13    3.0    1.0   33.500
# 14    3.0    2.0  123.000
# 15    3.0    3.0  221.750

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')
ax.set_xlabel('Alpha')
ax.set_ylabel('Gamma')
ax.set_zlabel('Score')
ax.axes.set_xticks([0,1,2,3])
ax.axes.set_yticks([0,1,2,3])
ax.axes.set_xticklabels([0.001, 0.01, 0.1, 0.2])
ax.axes.set_yticklabels([0.001, 0.01, 0.1, 0.2])
surf=ax.plot_trisurf(df['Alpha'], df['Gamma'], df['Score'], cmap=plt.cm.viridis, linewidth=0.2)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
